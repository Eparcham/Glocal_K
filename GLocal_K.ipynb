# %% [markdown]
# <a href="https://colab.research.google.com/github/Eparcham/Glocal_K/blob/main/GLocal_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
from time import time
from scipy.sparse import csc_matrix
import tensorflow as tf
import numpy as np
import h5py
# Out:
# TensorFlow 1.x selected.

# %%
print(tf.__version__)
# Out:
# 1.15.2

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/Douban_monti/
#   inflating: data/Douban_monti/douban_monti_dataset.mat
#    creating: data/MovieLens_100K/
#   inflating: data/MovieLens_100K/movielens_100k_u1.base
#   inflating: data/MovieLens_100K/movielens_100k_u1.test
#    creating: data/MovieLens_1M/
#   inflating: data/MovieLens_1M/movielens_1m_dataset.dat

# %% [markdown]
# # Data Loader Function

# %%
def load_data_100k(path='./', delimiter='\t'):

    train = np.loadtxt(path+'movielens_100k_u1.base', skiprows=0, delimiter=delimiter).astype('int32')
    test = np.loadtxt(path+'movielens_100k_u1.test', skiprows=0, delimiter=delimiter).astype('int32')
    total = np.concatenate((train, test), axis=0)

    n_u = np.unique(total[:,0]).size  # num of users
    n_m = np.unique(total[:,1]).size  # num of movies
    n_train = train.shape[0]  # num of training ratings
    n_test = test.shape[0]  # num of test ratings

    train_r = np.zeros((n_m, n_u), dtype='float32')
    test_r = np.zeros((n_m, n_u), dtype='float32')

    for i in range(n_train):
        train_r[train[i,1]-1, train[i,0]-1] = train[i,2]

    for i in range(n_test):
        test_r[test[i,1]-1, test[i,0]-1] = test[i,2]

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_train))
    print('num of test ratings: {}'.format(n_test))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %%
def load_data_1m(path='./', delimiter='::', frac=0.1, seed=1234):

    tic = time()
    print('reading data...')
    data = np.loadtxt(path+'movielens_1m_dataset.dat', skiprows=0, delimiter=delimiter).astype('int32')
    print('taken', time() - tic, 'seconds')

    n_u = np.unique(data[:,0]).size  # num of users
    n_m = np.unique(data[:,1]).size  # num of movies
    n_r = data.shape[0]  # num of ratings

    udict = {}
    for i, u in enumerate(np.unique(data[:,0]).tolist()):
        udict[u] = i
    mdict = {}
    for i, m in enumerate(np.unique(data[:,1]).tolist()):
        mdict[m] = i

    np.random.seed(seed)
    idx = np.arange(n_r)
    np.random.shuffle(idx)

    train_r = np.zeros((n_m, n_u), dtype='float32')
    test_r = np.zeros((n_m, n_u), dtype='float32')

    for i in range(n_r):
        u_id = data[idx[i], 0]
        m_id = data[idx[i], 1]
        r = data[idx[i], 2]

        if i < int(frac * n_r):
            test_r[mdict[m_id], udict[u_id]] = r
        else:
            train_r[mdict[m_id], udict[u_id]] = r

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_r - int(frac * n_r)))
    print('num of test ratings: {}'.format(int(frac * n_r)))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %%
def load_matlab_file(path_file, name_field):
    
    db = h5py.File(path_file, 'r')
    ds = db[name_field]

    try:
        if 'ir' in ds.keys():
            data = np.asarray(ds['data'])
            ir   = np.asarray(ds['ir'])
            jc   = np.asarray(ds['jc'])
            out  = csc_matrix((data, ir, jc)).astype(np.float32)
    except AttributeError:
        out = np.asarray(ds).astype(np.float32).T

    db.close()

    return out

# %%
def load_data_monti(path='./'):

    M = load_matlab_file(path+'douban_monti_dataset.mat', 'M')
    Otraining = load_matlab_file(path+'douban_monti_dataset.mat', 'Otraining') * M
    Otest = load_matlab_file(path+'douban_monti_dataset.mat', 'Otest') * M

    n_u = M.shape[0]  # num of users
    n_m = M.shape[1]  # num of movies
    n_train = Otraining[np.where(Otraining)].size  # num of training ratings
    n_test = Otest[np.where(Otest)].size  # num of test ratings

    train_r = Otraining.T
    test_r = Otest.T

    train_m = np.greater(train_r, 1e-12).astype('float32')  # masks indicating non-zero entries
    test_m = np.greater(test_r, 1e-12).astype('float32')

    print('data matrix loaded')
    print('num of users: {}'.format(n_u))
    print('num of movies: {}'.format(n_m))
    print('num of training ratings: {}'.format(n_train))
    print('num of test ratings: {}'.format(n_test))

    return n_m, n_u, train_r, train_m, test_r, test_m

# %% [markdown]
# # Load Data

# %%
# Insert the path of a data directory by yourself (e.g., '/content/.../data')
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
data_path = 'data'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Select a dataset among 'ML-1M', 'ML-100K', and 'Douban'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
dataset = 'ML-100K'
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Data Load
try:
    if dataset == 'ML-100K':
        path = data_path + '/MovieLens_100K/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_100k(path=path, delimiter='\t')

    elif dataset == 'ML-1M':
        path = data_path + '/MovieLens_1M/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_1m(path=path, delimiter='::', frac=0.1, seed=1234)

    elif dataset == 'Douban':
        path = data_path + '/Douban_monti/'
        n_m, n_u, train_r, train_m, test_r, test_m = load_data_monti(path=path)

    else:
        raise ValueError

except ValueError:
    print('Error: Unable to load data')
# Out:
# data matrix loaded
# num of users: 943
# num of movies: 1682
# num of training ratings: 80000
# num of test ratings: 20000

# %% [markdown]
# # Hyperparameter Settings

# %%
# Common hyperparameter settings
n_hid = 500
n_dim = 5
n_layers = 2
gk_size = 3

# %%
# Different hyperparameter settings for each dataset
if dataset == 'ML-100K':
    lambda_2 = 20.  # l2 regularisation
    lambda_s = 0.006
    iter_p = 5  # optimisation
    iter_f = 5
    epoch_p = 30  # training epoch
    epoch_f = 60
    dot_scale = 1  # scaled dot product

elif dataset == 'ML-1M':
    lambda_2 = 70.
    lambda_s = 0.018
    iter_p = 50
    iter_f = 10
    epoch_p = 20
    epoch_f = 30
    dot_scale = 0.5

elif dataset == 'Douban':
    lambda_2 = 10.
    lambda_s = 0.022
    iter_p = 5
    iter_f = 5
    epoch_p = 20
    epoch_f = 60
    dot_scale = 2

# %%
R = tf.placeholder("float", [n_m, n_u])

# %% [markdown]
# # Network Function

# %%
def local_kernel(u, v):

    dist = tf.norm(u - v, ord=2, axis=2)
    hat = tf.maximum(0., 1. - dist**2)

    return hat

# %%
def kernel_layer(x, n_hid=n_hid, n_dim=n_dim, activation=tf.nn.sigmoid, lambda_s=lambda_s, lambda_2=lambda_2, name=''):

    with tf.variable_scope(name, reuse=tf.AUTO_REUSE):
        W = tf.get_variable('W', [x.shape[1], n_hid])
        n_in = x.get_shape().as_list()[1]
        u = tf.get_variable('u', initializer=tf.random.truncated_normal([n_in, 1, n_dim], 0., 1e-3))
        v = tf.get_variable('v', initializer=tf.random.truncated_normal([1, n_hid, n_dim], 0., 1e-3))
        b = tf.get_variable('b', [n_hid])

    w_hat = local_kernel(u, v)
    
    sparse_reg = tf.contrib.layers.l2_regularizer(lambda_s)
    sparse_reg_term = tf.contrib.layers.apply_regularization(sparse_reg, [w_hat])
    
    l2_reg = tf.contrib.layers.l2_regularizer(lambda_2)
    l2_reg_term = tf.contrib.layers.apply_regularization(l2_reg, [W])

    W_eff = W * w_hat  # Local kernelised weight matrix
    y = tf.matmul(x, W_eff) + b
    y = activation(y)

    return y, sparse_reg_term + l2_reg_term

# %%
def global_kernel(input, gk_size, dot_scale):

    avg_pooling = tf.reduce_mean(input, axis=1)  # Item (axis=1) based average pooling
    avg_pooling = tf.reshape(avg_pooling, [1, -1])
    n_kernel = avg_pooling.shape[1].value

    conv_kernel = tf.get_variable('conv_kernel', initializer=tf.random.truncated_normal([n_kernel, gk_size**2], stddev=0.1))
    gk = tf.matmul(avg_pooling, conv_kernel) * dot_scale  # Scaled dot product
    gk = tf.reshape(gk, [gk_size, gk_size, 1, 1])

    return gk

# %%
def global_conv(input, W):

    input = tf.reshape(input, [1, input.shape[0], input.shape[1], 1])
    conv2d = tf.nn.relu(tf.nn.conv2d(input, W, strides=[1,1,1,1], padding='SAME'))

    return tf.reshape(conv2d, [conv2d.shape[1], conv2d.shape[2]])

# %% [markdown]
# # Network Instantiation

# %% [markdown]
# ## Pre-training

# %%
y = R
reg_losses = None

for i in range(n_layers):
    y, reg_loss = kernel_layer(y, name=str(i))
    reg_losses = reg_loss if reg_losses is None else reg_losses + reg_loss

pred_p, reg_loss = kernel_layer(y, n_u, activation=tf.identity, name='out')
reg_losses = reg_losses + reg_loss

# L2 loss
diff = train_m * (train_r - pred_p)
sqE = tf.nn.l2_loss(diff)
loss_p = sqE + reg_losses

optimizer_p = tf.contrib.opt.ScipyOptimizerInterface(loss_p, options={'disp': True, 'maxiter': iter_p, 'maxcor': 10}, method='L-BFGS-B')
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## Fine-tuning

# %%
y = R
reg_losses = None

for i in range(n_layers):
    y, _ = kernel_layer(y, name=str(i))

y_dash, _ = kernel_layer(y, n_u, activation=tf.identity, name='out')

gk = global_kernel(y_dash, gk_size, dot_scale)  # Global kernel
y_hat = global_conv(train_r, gk)  # Global kernel-based rating matrix

for i in range(n_layers):
    y_hat, reg_loss = kernel_layer(y_hat, name=str(i))
    reg_losses = reg_loss if reg_losses is None else reg_losses + reg_loss

pred_f, reg_loss = kernel_layer(y_hat, n_u, activation=tf.identity, name='out')
reg_losses = reg_losses + reg_loss

# L2 loss
diff = train_m * (train_r - pred_f)
sqE = tf.nn.l2_loss(diff)
loss_f = sqE + reg_losses

optimizer_f = tf.contrib.opt.ScipyOptimizerInterface(loss_f, options={'disp': True, 'maxiter': iter_f, 'maxcor': 10}, method='L-BFGS-B')

# %% [markdown]
# # Evaluation code

# %%
def dcg_k(score_label, k):
    dcg, i = 0., 0
    for s in score_label:
        if i < k:
            dcg += (2**s[1]-1) / np.log2(2+i)
            i += 1
    return dcg

# %%
def ndcg_k(y_hat, y, k):
    score_label = np.stack([y_hat, y], axis=1).tolist()
    score_label = sorted(score_label, key=lambda d:d[0], reverse=True)
    score_label_ = sorted(score_label, key=lambda d:d[1], reverse=True)
    norm, i = 0., 0
    for s in score_label_:
        if i < k:
            norm += (2**s[1]-1) / np.log2(2+i)
            i += 1
    dcg = dcg_k(score_label, k)
    return dcg / norm

# %%
def call_ndcg(y_hat, y):
    ndcg_sum, num = 0, 0
    y_hat, y = y_hat.T, y.T
    n_users = y.shape[0]

    for i in range(n_users):
        y_hat_i = y_hat[i][np.where(y[i])]
        y_i = y[i][np.where(y[i])]

        if y_i.shape[0] < 2:
            continue

        ndcg_sum += ndcg_k(y_hat_i, y_i, y_i.shape[0])  # user-wise calculation
        num += 1

    return ndcg_sum / num

# %% [markdown]
# # Training and Test Loop

# %%
best_rmse_ep, best_mae_ep, best_ndcg_ep = 0, 0, 0
best_rmse, best_mae, best_ndcg = float("inf"), float("inf"), 0

time_cumulative = 0
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for i in range(epoch_p):
        tic = time()
        optimizer_p.minimize(sess, feed_dict={R: train_r})
        pre = sess.run(pred_p, feed_dict={R: train_r})

        t = time() - tic
        time_cumulative += t
        
        error = (test_m * (np.clip(pre, 1., 5.) - test_r) ** 2).sum() / test_m.sum()  # test error
        test_rmse = np.sqrt(error)

        error_train = (train_m * (np.clip(pre, 1., 5.) - train_r) ** 2).sum() / train_m.sum()  # train error
        train_rmse = np.sqrt(error_train)

        print('.-^-._' * 12)
        print('PRE-TRAINING')
        print('Epoch:', i+1, 'test rmse:', test_rmse, 'train rmse:', train_rmse)
        print('Time:', t, 'seconds')
        print('Time cumulative:', time_cumulative, 'seconds')
        print('.-^-._' * 12)

    for i in range(epoch_f):
        tic = time()
        optimizer_f.minimize(sess, feed_dict={R: train_r})
        pre = sess.run(pred_f, feed_dict={R: train_r})

        t = time() - tic
        time_cumulative += t
        
        error = (test_m * (np.clip(pre, 1., 5.) - test_r) ** 2).sum() / test_m.sum()  # test error
        test_rmse = np.sqrt(error)

        error_train = (train_m * (np.clip(pre, 1., 5.) - train_r) ** 2).sum() / train_m.sum()  # train error
        train_rmse = np.sqrt(error_train)

        test_mae = (test_m * np.abs(np.clip(pre, 1., 5.) - test_r)).sum() / test_m.sum()
        train_mae = (train_m * np.abs(np.clip(pre, 1., 5.) - train_r)).sum() / train_m.sum()

        test_ndcg = call_ndcg(np.clip(pre, 1., 5.), test_r)
        train_ndcg = call_ndcg(np.clip(pre, 1., 5.), train_r)

        if test_rmse < best_rmse:
            best_rmse = test_rmse
            best_rmse_ep = i+1

        if test_mae < best_mae:
            best_mae = test_mae
            best_mae_ep = i+1

        if best_ndcg < test_ndcg:
            best_ndcg = test_ndcg
            best_ndcg_ep = i+1

        print('.-^-._' * 12)
        print('FINE-TUNING')
        print('Epoch:', i+1, 'test rmse:', test_rmse, 'test mae:', test_mae, 'test ndcg:', test_ndcg)
        print('Epoch:', i+1, 'train rmse:', train_rmse, 'train mae:', train_mae, 'train ndcg:', train_ndcg)
        print('Time:', t, 'seconds')
        print('Time cumulative:', time_cumulative, 'seconds')
        print('.-^-._' * 12)
# Out:
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 87075.914062
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 1 test rmse: 1.4362917 train rmse: 1.2655668
# Time: 2.9686858654022217 seconds
# Time cumulative: 2.9686858654022217 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 63505.445312
#   Number of iterations: 5
#   Number of functions evaluations: 6
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 2 test rmse: 1.0985593 train rmse: 1.0197043
# Time: 3.2020633220672607 seconds
# Time cumulative: 6.170749187469482 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 60598.734375
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 3 test rmse: 1.0300006 train rmse: 0.98675644
# Time: 2.883458375930786 seconds
# Time cumulative: 9.054207563400269 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 59216.656250
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 4 test rmse: 1.0118811 train rmse: 0.9706145
# Time: 2.7737855911254883 seconds
# Time cumulative: 11.827993154525757 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 58125.750000
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 5 test rmse: 0.9993055 train rmse: 0.9594156
# Time: 2.541849136352539 seconds
# Time cumulative: 14.369842290878296 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 57278.476562
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 6 test rmse: 0.98903006 train rmse: 0.94978845
# Time: 2.4716782569885254 seconds
# Time cumulative: 16.84152054786682 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 56225.648438
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 7 test rmse: 0.978911 train rmse: 0.9403864
# Time: 1.7037312984466553 seconds
# Time cumulative: 18.545251846313477 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 55658.578125
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 8 test rmse: 0.97275597 train rmse: 0.9338242
# Time: 1.3303396701812744 seconds
# Time cumulative: 19.87559151649475 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 54396.980469
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 9 test rmse: 0.9652562 train rmse: 0.92480826
# Time: 1.3466620445251465 seconds
# Time cumulative: 21.222253561019897 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 53811.695312
#   Number of iterations: 5
#   Number of functions evaluations: 9
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 10 test rmse: 0.95988125 train rmse: 0.91853005
# Time: 1.357473373413086 seconds
# Time cumulative: 22.579726934432983 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 52673.914062
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 11 test rmse: 0.9586987 train rmse: 0.9139645
# Time: 1.283266305923462 seconds
# Time cumulative: 23.862993240356445 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 51712.652344
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 12 test rmse: 0.94804764 train rmse: 0.90150183
# Time: 1.3491528034210205 seconds
# Time cumulative: 25.212146043777466 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 50871.289062
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 13 test rmse: 0.9470927 train rmse: 0.89722276
# Time: 1.2918050289154053 seconds
# Time cumulative: 26.50395107269287 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 50248.148438
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 14 test rmse: 0.9398794 train rmse: 0.8893493
# Time: 1.3023734092712402 seconds
# Time cumulative: 27.80632448196411 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 49221.679688
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 15 test rmse: 0.9375659 train rmse: 0.8843057
# Time: 1.332155466079712 seconds
# Time cumulative: 29.138479948043823 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 48586.960938
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 16 test rmse: 0.9303766 train rmse: 0.87611437
# Time: 1.3725385665893555 seconds
# Time cumulative: 30.51101851463318 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 48167.894531
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 17 test rmse: 0.9300566 train rmse: 0.8736652
# Time: 1.3277711868286133 seconds
# Time cumulative: 31.838789701461792 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 47873.000000
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch: 18 test rmse: 0.9269906 train rmse: 0.8704925
# Time: 1.2999114990234375 seconds
# Time cumulative: 33.13870120048523 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 47236.656250
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# PRE-TRAINING
# Epoch:
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 28 test rmse: 0.89026386 test mae: 0.69741404 test ndcg: 0.9037852240212347
# Epoch: 28 train rmse: 0.74753094 train mae: 0.5862496 train ndcg: 0.9379134498846139
# Time: 1.4211513996124268 seconds
# Time cumulative: 93.66462230682373 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 35027.058594
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 29 test rmse: 0.8905914 test mae: 0.69648826 test ndcg: 0.9036526431219611
# Epoch: 29 train rmse: 0.74440104 train mae: 0.5833688 train ndcg: 0.939428256060061
# Time: 1.4059698581695557 seconds
# Time cumulative: 95.07059216499329 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34776.886719
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 30 test rmse: 0.89022964 test mae: 0.6974305 test ndcg: 0.9036896603220586
# Epoch: 30 train rmse: 0.74061996 train mae: 0.5807813 train ndcg: 0.9397304136453298
# Time: 1.3663275241851807 seconds
# Time cumulative: 96.43691968917847 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34617.113281
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 31 test rmse: 0.89117604 test mae: 0.69797486 test ndcg: 0.9035103534100262
# Epoch: 31 train rmse: 0.7390823 train mae: 0.57935363 train ndcg: 0.9401211937763317
# Time: 1.4452173709869385 seconds
# Time cumulative: 97.8821370601654 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34485.433594
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 32 test rmse: 0.89028144 test mae: 0.6972096 test ndcg: 0.9035994986111426
# Epoch: 32 train rmse: 0.73714733 train mae: 0.5778179 train ndcg: 0.9403668128806537
# Time: 1.3836445808410645 seconds
# Time cumulative: 99.26578164100647 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34353.566406
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 33 test rmse: 0.89027387 test mae: 0.6970227 test ndcg: 0.9035833172310843
# Epoch: 33 train rmse: 0.7358038 train mae: 0.57677263 train ndcg: 0.940868396017554
# Time: 1.3933377265930176 seconds
# Time cumulative: 100.65911936759949 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34246.871094
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 34 test rmse: 0.89038944 test mae: 0.69714427 test ndcg: 0.9029592555765988
# Epoch: 34 train rmse: 0.73437077 train mae: 0.57568073 train ndcg: 0.9410261181401561
# Time: 1.4242174625396729 seconds
# Time cumulative: 102.08333683013916 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34165.132812
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 35 test rmse: 0.8902824 test mae: 0.69721895 test ndcg: 0.9029569701254655
# Epoch: 35 train rmse: 0.7334337 train mae: 0.57506675 train ndcg: 0.9413493241843405
# Time: 1.4169049263000488 seconds
# Time cumulative: 103.50024175643921 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 34084.281250
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 36 test rmse: 0.89068806 test mae: 0.6971375 test ndcg: 0.9033152150445144
# Epoch: 36 train rmse: 0.7327598 train mae: 0.5744638 train ndcg: 0.9415263993269979
# Time: 1.4444518089294434 seconds
# Time cumulative: 104.94469356536865 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33967.578125
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 37 test rmse: 0.89025676 test mae: 0.69675076 test ndcg: 0.9036536547826414
# Epoch: 37 train rmse: 0.7311263 train mae: 0.5730025 train ndcg: 0.9418302064434062
# Time: 1.4178686141967773 seconds
# Time cumulative: 106.36256217956543 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33877.695312
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 38 test rmse: 0.8902152 test mae: 0.69658786 test ndcg: 0.9036907948725298
# Epoch: 38 train rmse: 0.72991765 train mae: 0.571905 train ndcg: 0.9420199455703069
# Time: 1.385962963104248 seconds
# Time cumulative: 107.74852514266968 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33663.964844
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 39 test rmse: 0.8902889 test mae: 0.6968325 test ndcg: 0.9039442693255948
# Epoch: 39 train rmse: 0.72801226 train mae: 0.5706117 train ndcg: 0.9424250333349806
# Time: 1.3769276142120361 seconds
# Time cumulative: 109.12545275688171 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33532.714844
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 40 test rmse: 0.89013934 test mae: 0.69638133 test ndcg: 0.9029892103937436
# Epoch: 40 train rmse: 0.72603756 train mae: 0.56880504 train ndcg: 0.9427176546674491
# Time: 1.4051282405853271 seconds
# Time cumulative: 110.53058099746704 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33409.503906
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 41 test rmse: 0.8902629 test mae: 0.69658756 test ndcg: 0.9041447466426529
# Epoch: 41 train rmse: 0.72448885 train mae: 0.5677345 train ndcg: 0.9430801008212727
# Time: 1.396308422088623 seconds
# Time cumulative: 111.92688941955566 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33236.234375
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 42 test rmse: 0.8907797 test mae: 0.6971882 test ndcg: 0.9034476758959632
# Epoch: 42 train rmse: 0.7227082 train mae: 0.5666672 train ndcg: 0.9434651504096336
# Time: 1.4295289516448975 seconds
# Time cumulative: 113.35641837120056 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 33132.140625
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 43 test rmse: 0.8902629 test mae: 0.6967206 test ndcg: 0.9040705245672621
# Epoch: 43 train rmse: 0.72119653 train mae: 0.5652797 train ndcg: 0.9438565058408824
# Time: 1.4348335266113281 seconds
# Time cumulative: 114.79125189781189 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32986.125000
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 44 test rmse: 0.89089286 test mae: 0.697188 test ndcg: 0.9037602771836879
# Epoch: 44 train rmse: 0.71967643 train mae: 0.5641032 train ndcg: 0.9441887442509528
# Time: 1.4422390460968018 seconds
# Time cumulative: 116.23349094390869 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32871.808594
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 45 test rmse: 0.890666 test mae: 0.6969088 test ndcg: 0.9041312554574508
# Epoch: 45 train rmse: 0.71799624 train mae: 0.56269604 train ndcg: 0.9444919505013555
# Time: 1.3728408813476562 seconds
# Time cumulative: 117.60633182525635 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32710.523438
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 46 test rmse: 0.8908652 test mae: 0.69748837 test ndcg: 0.9043678959568906
# Epoch: 46 train rmse: 0.71640044 train mae: 0.5620027 train ndcg: 0.9449893153379392
# Time: 1.4414374828338623 seconds
# Time cumulative: 119.04776930809021 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32598.765625
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 47 test rmse: 0.89044005 test mae: 0.6964669 test ndcg: 0.904746494776546
# Epoch: 47 train rmse: 0.7146147 train mae: 0.55980325 train ndcg: 0.9452881101307306
# Time: 1.4113731384277344 seconds
# Time cumulative: 120.45914244651794 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32442.576172
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 48 test rmse: 0.8908126 test mae: 0.6968966 test ndcg: 0.9040308778353945
# Epoch: 48 train rmse: 0.71304923 train mae: 0.55856633 train ndcg: 0.9456625911650159
# Time: 1.4472992420196533 seconds
# Time cumulative: 121.9064416885376 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32329.720703
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 49 test rmse: 0.89073586 test mae: 0.69658786 test ndcg: 0.9042308512251755
# Epoch: 49 train rmse: 0.7113358 train mae: 0.5571996 train ndcg: 0.9461195826363412
# Time: 1.8009436130523682 seconds
# Time cumulative: 123.70738530158997 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32224.972656
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 50 test rmse: 0.8906819 test mae: 0.6965829 test ndcg: 0.903964177362607
# Epoch: 50 train rmse: 0.70987856 train mae: 0.55596566 train ndcg: 0.9462685078411812
# Time: 1.4518237113952637 seconds
# Time cumulative: 125.15920901298523 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32157.714844
#   Number of iterations: 5
#   Number of functions evaluations: 7
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 51 test rmse: 0.8908256 test mae: 0.69673324 test ndcg: 0.90449948688706
# Epoch: 51 train rmse: 0.7090029 train mae: 0.5553286 train ndcg: 0.9463453835823068
# Time: 1.4094362258911133 seconds
# Time cumulative: 126.56864523887634 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32083.759766
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 52 test rmse: 0.8906684 test mae: 0.6966989 test ndcg: 0.9046842689136443
# Epoch: 52 train rmse: 0.7080996 train mae: 0.55455416 train ndcg: 0.9466520944793031
# Time: 1.410071611404419 seconds
# Time cumulative: 127.97871685028076 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 32004.796875
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 53 test rmse: 0.89064837 test mae: 0.696398 test ndcg: 0.904380812214758
# Epoch: 53 train rmse: 0.7069736 train mae: 0.55352855 train ndcg: 0.9467093369100683
# Time: 1.462263584136963 seconds
# Time cumulative: 129.44098043441772 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31909.933594
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 54 test rmse: 0.8909719 test mae: 0.6967324 test ndcg: 0.9044112612875581
# Epoch: 54 train rmse: 0.7058312 train mae: 0.55274254 train ndcg: 0.947141355273052
# Time: 1.4518606662750244 seconds
# Time cumulative: 130.89284110069275 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31825.882812
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 55 test rmse: 0.8913933 test mae: 0.69682825 test ndcg: 0.9043060419870048
# Epoch: 55 train rmse: 0.70468336 train mae: 0.55183 train ndcg: 0.9472307332672653
# Time: 1.427572250366211 seconds
# Time cumulative: 132.32041335105896 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31721.861328
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 56 test rmse: 0.89106935 test mae: 0.6965687 test ndcg: 0.9043229324717561
# Epoch: 56 train rmse: 0.7033501 train mae: 0.5506194 train ndcg: 0.9474494863577388
# Time: 1.461073637008667 seconds
# Time cumulative: 133.78148698806763 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31642.462891
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 57 test rmse: 0.8908575 test mae: 0.69622666 test ndcg: 0.9037404119974183
# Epoch: 57 train rmse: 0.7022379 train mae: 0.54970926 train ndcg: 0.9474326342063056
# Time: 1.4040298461914062 seconds
# Time cumulative: 135.18551683425903 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31565.322266
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 58 test rmse: 0.8909097 test mae: 0.6964389 test ndcg: 0.9040267077411364
# Epoch: 58 train rmse: 0.7011323 train mae: 0.54895365 train ndcg: 0.9477650970915391
# Time: 1.4650673866271973 seconds
# Time cumulative: 136.65058422088623 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31488.335938
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 59 test rmse: 0.8909654 test mae: 0.6963648 test ndcg: 0.9037159455142372
# Epoch: 59 train rmse: 0.7001643 train mae: 0.54802203 train ndcg: 0.9480975915399306
# Time: 1.4280545711517334 seconds
# Time cumulative: 138.07863879203796 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 31382.525391
#   Number of iterations: 5
#   Number of functions evaluations: 8
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# FINE-TUNING
# Epoch: 60 test rmse: 0.8912487 test mae: 0.6969721 test ndcg: 0.9039161991844813
# Epoch: 60 train rmse: 0.6987906 train mae: 0.5471847 train ndcg: 0.948492586380336
# Time: 1.426973581314087 seconds
# Time cumulative: 139.50561237335205 seconds
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %%
# Final result
print('Epoch:', best_rmse_ep, ' best rmse:', best_rmse)
print('Epoch:', best_mae_ep, ' best mae:', best_mae)
print('Epoch:', best_ndcg_ep, ' best ndcg:', best_ndcg)
# Out:
# Epoch: 40  best rmse: 0.89013934
# Epoch: 57  best mae: 0.69622666
# Epoch: 47  best ndcg: 0.904746494776546
